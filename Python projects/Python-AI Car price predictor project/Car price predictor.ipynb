# %% [markdown]
# # Used cars database

# %% [markdown]
# ### I used the used car data set because it had a variety of categorical and numerical data and allows you to explore different ways of dealing with missing data, the goal is to predict a car's price.

# %% [markdown]
# ## Import Libraries and Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("Used Cars.csv", encoding="ISO-8859-1",nrows=3000)

# %%
data.sample(10)
# Out:
#               dateCrawled                                               name  \
# 2885  2016-03-14 13:25:25                  A4_1.9_TDI_S_line!_131PS_Schwartz
# 238   2016-03-12 08:51:00                          Suzuki_LJ_80_fuer_Bastler
# 2807  2016-03-21 13:51:16                              BMW_X3_xDrive30d_Aut.
# 1879  2016-04-01 23:55:15                        Opel_Meriva_1.6_KLIMA_SERVO
# 925   2016-03-15 22:49:38      Ford_Fiesta__top_fuer_Anfaenger_oder_Familie_
# 2755  2016-03-31 19:41:11                                        VW_Polo_1_6
# 428   2016-03-29 18:45:21                                       BMW_530D_E39
# 56    2016-03-21 01:59:07                               BMW_435i_Sport_coupe
# 1350  2016-03-21 20:49:17  Ford_Ka_Futura_1_Hand_Klima_Kein_Rost_Alufelge...
# 112   2016-03-22 17:44:26                                 530d_XDRIVE_235_PS
#
#       seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 2885  privat   Angebot   2500     test       kombi                2003
# 238   privat   Angebot   1000  control         suv                1982
# 2807  privat   Angebot  36500     test         suv                2011
# 1879  privat   Angebot   1890  control         NaN                2017
# 925   privat   Angebot   1199  control  kleinwagen                2000
# 2755  privat   Angebot    350  control  kleinwagen                1997
# 428   privat   Angebot   3400  control   limousine                2002
# 56    privat   Angebot  39600     test       coupe                2014
# 1350  privat   Angebot   1000     test  kleinwagen                2000
# 112   privat   Angebot   7300  control   limousine                2009
#
#         gearbox  powerPS    model  kilometer  monthOfRegistration fuelType  \
# 2885    manuell      131       a4     150000                    5   diesel
# 238     manuell       41   andere     150000                   11   benzin
# 2807  automatik      258  x_reihe      70000                   11   diesel
# 1879    manuell       86   meriva     125000                    9   benzin
# 925     manuell       60   fiesta     125000                    0   benzin
# 2755    manuell        0     polo     150000                    7      NaN
# 428   automatik      193      5er     150000                   12   diesel
# 56    automatik      306   andere      30000                    7   benzin
# 1350    manuell       60       ka      60000                    6   benzin
# 112   automatik      235      5er     100000                    3   diesel
#
#            brand notRepairedDamage          dateCreated  nrOfPictures  \
# 2885        audi              nein  2016-03-14 00:00:00             0
# 238       suzuki               NaN  2016-03-12 00:00:00             0
# 2807         bmw              nein  2016-03-21 00:00:00             0
# 1879        opel               NaN  2016-04-01 00:00:00             0
# 925         ford              nein  2016-03-15 00:00:00             0
# 2755  volkswagen                ja  2016-03-31 00:00:00             0
# 428          bmw               NaN  2016-03-29 00:00:00             0
# 56           bmw              nein  2016-03-21 00:00:00             0
# 1350        ford              nein  2016-03-21 00:00:00             0
# 112          bmw              nein  2016-03-22 00:00:00             0
#
#       postalCode             lastSeen
# 2885       63225  2016-03-14 14:06:55
# 238        56337  2016-03-13 00:45:46
# 2807       71686  2016-04-06 09:46:32
# 1879       45772  2016-04-06 05:16:23
# 925        28199  2016-03-20 23:44:46
# 2755       47259  2016-04-06 13:45:28
# 428        24143  2016-04-06 04:17:16
# 56         10435  2016-04-03 23:16:31
# 1350       63329  2016-03-22 23:37:03
# 112        83022  2016-03-22 17:44:26

# %% [markdown]
# ## Informations about the dataset

# %%
data.shape
# Out:
# (3000, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 20 columns):
# dateCrawled            3000 non-null object
# name                   3000 non-null object
# seller                 3000 non-null object
# offerType              3000 non-null object
# price                  3000 non-null int64
# abtest                 3000 non-null object
# vehicleType            2675 non-null object
# yearOfRegistration     3000 non-null int64
# gearbox                2841 non-null object
# powerPS                3000 non-null int64
# model                  2850 non-null object
# kilometer              3000 non-null int64
# monthOfRegistration    3000 non-null int64
# fuelType               2715 non-null object
# brand                  3000 non-null object
# notRepairedDamage      2405 non-null object
# dateCreated            3000 non-null object
# nrOfPictures           3000 non-null int64
# postalCode             3000 non-null int64
# lastSeen               3000 non-null object
# dtypes: int64(7), object(13)
# memory usage: 468.9+ KB

# %%
data.describe()
# Out:
#                price  yearOfRegistration      powerPS      kilometer  \
# count    3000.000000         3000.000000  3000.000000    3000.000000
# mean     5889.077000         2003.229667   113.406000  125646.666667
# std     13106.442948           18.034301    81.147204   39886.657803
# min         0.000000         1111.000000     0.000000    5000.000000
# 25%      1200.000000         1999.000000    73.750000  125000.000000
# 50%      2999.000000         2004.000000   105.000000  150000.000000
# 75%      7242.500000         2008.000000   150.000000  150000.000000
# max    579000.000000         2018.000000  1799.000000  150000.000000
#
#        monthOfRegistration  nrOfPictures    postalCode
# count          3000.000000        3000.0   3000.000000
# mean              5.892667           0.0  51135.041667
# std               3.733246           0.0  25861.489861
# min               0.000000           0.0   1067.000000
# 25%               3.000000           0.0  30912.000000
# 50%               6.000000           0.0  50677.500000
# 75%               9.000000           0.0  71364.000000
# max              12.000000           0.0  99974.000000

# %% [markdown]
# # Cleaning data

# %%
plt.subplots(figsize=(15,10))
plt.subplot(321)
data.seller.value_counts(100).plot(kind='bar', title="Seller Proportion", fontsize=18)
plt.xticks(rotation=0, fontsize=12)
plt.yticks(rotation=0, fontsize=12)

plt.subplot(322)
data.offerType.value_counts(100).plot(kind='bar', title='Offer Type Proportion', fontsize=18)
plt.xticks(rotation=0, fontsize=12)
plt.yticks(rotation=0, fontsize=12)
plt.show()

plt.subplot(326)
data.nrOfPictures.value_counts(100).plot(kind='bar', title='Number Of Pictures Proportion', fontsize=18)
plt.xticks(rotation=0, fontsize=12)
plt.yticks(rotation=0, fontsize=12)
plt.show()

# %%
sns.barplot(x = 'lastSeen', y = 'price', data = data)

# %%
sns.barplot(x = 'dateCreated', y = 'price', data = data)

# %%
sns.barplot(x = 'abtest', y = 'price', data = data)

# %%
sns.barplot(x = 'monthOfRegistration', y = 'price', data = data)

# %%
sns.barplot(x = 'dateCrawled', y = 'price', data = data)

# %% [markdown]
# #### The features seller, offerType and nrOfPictures are very sparse  representing a single category therefore they will have no effect on model performance so we drop these features. Moreover abtest variable does not provide any meaningful information to predict the price of the vehicle. We also remove dateCrawled, dateCreated and lastSeen features which are less important for our problem to predict price.

# %%
data = data.drop(['seller','offerType','abtest','nrOfPictures','dateCrawled', 'dateCreated', 'lastSeen', 'postalCode'], axis=1)
data1 = data.drop(['monthOfRegistration'], axis=1)

# %% [markdown]
# ### Removing the duplicates

# %%
df1 = data1.drop_duplicates(['name','price','vehicleType','yearOfRegistration','gearbox','powerPS','model','kilometer','fuelType','notRepairedDamage'])

# %% [markdown]
# ### Removing the outliers

# %%
df= df1[(df1.yearOfRegistration <= 2016) & (df1.yearOfRegistration >= 1950) & (df1.price >= 50) & (df1.price <= 50000) & (df1.powerPS >= 5) & (df1.powerPS <= 400)]

# %% [markdown]
# ## Data Vizualization to help build the model(Preprocessing)

# %%
# Data Viz of the categorical data
plt.subplots(figsize=(15,15))
plt.subplot(322)
sns.countplot(x='notRepairedDamage', data=df)

plt.subplots(figsize=(15,15))
plt.subplot(322)
sns.countplot(x='brand', data=df)

plt.subplots(figsize=(15,15))
plt.subplot(322)
sns.countplot(x='fuelType', data=df)

plt.subplots(figsize=(15,15))
plt.subplot(322)
sns.countplot(x='gearbox', data=df)

plt.subplots(figsize=(15,15))
plt.subplot(322)
sns.countplot(x='vehicleType', data=df)

plt.subplots(figsize=(15,15))
plt.subplot(322)
sns.countplot(x='model', data=df)

# %%
# Data Viz of the numerical data
plt.subplots(figsize=(15,10))
plt.subplot(322)
sns.boxplot(df.price)

plt.subplots(figsize=(15,10))
plt.subplot(324)
sns.boxplot(df.powerPS)

plt.subplots(figsize=(15,10))
plt.subplot(326)
sns.boxplot(df.kilometer)

plt.subplots(figsize=(15,10))
plt.subplot(326)
sns.boxplot(df.yearOfRegistration)

# %% [markdown]
# ### Data viz of the corr between the features and the target

# %%
plt.subplots(figsize=(15,10))
plt.subplot(322)
sns.barplot(x = 'yearOfRegistration', y = 'price', data = df)

plt.subplots(figsize=(15,10))
plt.subplot(322)
sns.barplot(x = 'powerPS', y = 'price', data = df)

plt.subplots(figsize=(15,10))
plt.subplot(322)
sns.barplot(x = 'kilometer', y = 'price', data = df)

plt.subplots(figsize=(15,10))
plt.subplot(322)
sns.barplot(x = 'vehicleType', y = 'price', data = df)

plt.subplots(figsize=(15,10))
plt.subplot(322)
sns.barplot(x = 'gearbox', y = 'price', data = df)

plt.subplots(figsize=(15,10))
plt.subplot(322)
sns.barplot(x = 'fuelType', y = 'price', data = df)

plt.subplots(figsize=(15,10))
plt.subplot(322)
sns.barplot(x = 'notRepairedDamage', y = 'price', data = df)

# %% [markdown]
# ### Correlation

# %%
df.corr()
# Out:
#                        price  yearOfRegistration   powerPS  kilometer
# price               1.000000            0.467205  0.566092  -0.479364
# yearOfRegistration  0.467205            1.000000  0.155394  -0.360817
# powerPS             0.566092            0.155394  1.000000   0.015507
# kilometer          -0.479364           -0.360817  0.015507   1.000000

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, square=True, annot_kws={'fontsize':15})
plt.show()

# %% [markdown]
# ### Filling missing values and applying label encoder

# %%
df.isna().sum()
# Out:
# name                    0
# price                   0
# vehicleType            95
# yearOfRegistration      0
# gearbox                42
# powerPS                 0
# model                  81
# kilometer               0
# fuelType              123
# brand                   0
# notRepairedDamage     333
# dtype: int64

# %%
print(df.model.value_counts())
# Out:
# golf           193
# andere         170
# 3er            156
# a4              83
# 5er             78
#               ...
# range_rover      1
# phaeton          1
# q3               1
# 300c             1
# 6er              1
# Name: model, Length: 204, dtype: int64

# %%
print(df.vehicleType.value_counts())
# Out:
# limousine     703
# kleinwagen    530
# kombi         492
# bus           204
# cabrio        168
# coupe         150
# suv            99
# andere         27
# Name: vehicleType, dtype: int64

# %%
print(df.gearbox.value_counts())
# Out:
# manuell      1878
# automatik     548
# Name: gearbox, dtype: int64

# %%
print(df.fuelType.value_counts())
# Out:
# benzin    1534
# diesel     779
# lpg         29
# cng          1
# hybrid       1
# andere       1
# Name: fuelType, dtype: int64

# %%
print(df.notRepairedDamage.value_counts())
# Out:
# nein    1927
# ja       208
# Name: notRepairedDamage, dtype: int64

# %%
df['notRepairedDamage']=df['notRepairedDamage'].map({'ja': 1,'nein': 2})
df['fuelType']=df['fuelType'].map({'benzin': 1,'lpg': 2,'hybrid': 3,'andere': 4,'cng':5,'diesel':6})
df['gearbox']=df['gearbox'].map({'manuell': 1,'automatik': 2})
df['vehicleType']=df['vehicleType'].map({'kleinwagen': 1,'kombi': 2,'andere': 3,'limousine': 4,'bus':5,'cabrio':6,'coupe':7,'suv':8})

# %%
df.model = df['model'].fillna(method='ffill')
df['gearbox']=df['gearbox'].fillna(df['gearbox'].median())
df['notRepairedDamage']=df['notRepairedDamage'].fillna(df['notRepairedDamage'].median())
df['fuelType']=df['fuelType'].fillna(df['fuelType'].median())
df['vehicleType']=df['vehicleType'].fillna(df['vehicleType'].median())
df = df.drop(['name'], axis=1)

# %%
df.isna().sum()
# Out:
# price                 0
# vehicleType           0
# yearOfRegistration    0
# gearbox               0
# powerPS               0
# model                 1
# kilometer             0
# fuelType              0
# brand                 0
# notRepairedDamage     0
# dtype: int64

# %% [markdown]
# ### Data viz of the corr between the features and the target after filling the missing values and appliying laber encoder

# %%
plt.subplots(figsize=(15,10))
plt.subplot(322)
sns.barplot(x = 'yearOfRegistration', y = 'price', data = df)

plt.subplots(figsize=(15,10))
plt.subplot(322)
sns.barplot(x = 'powerPS', y = 'price', data = df)

plt.subplots(figsize=(15,10))
plt.subplot(322)
sns.barplot(x = 'kilometer', y = 'price', data = df)

plt.subplots(figsize=(15,10))
plt.subplot(322)
sns.barplot(x = 'vehicleType', y = 'price', data = df)

plt.subplots(figsize=(15,10))
plt.subplot(322)
sns.barplot(x = 'gearbox', y = 'price', data = df)

plt.subplots(figsize=(15,10))
plt.subplot(322)
sns.barplot(x = 'fuelType', y = 'price', data = df)

plt.subplots(figsize=(15,10))
plt.subplot(322)
sns.barplot(x = 'notRepairedDamage', y = 'price', data = df)

# %% [markdown]
# ### Correlation after filling the missing values and appliying laber encoder¶

# %%
df.corr()
# Out:
#                        price  vehicleType  yearOfRegistration   gearbox  \
# price               1.000000     0.335728            0.467205  0.329326
# vehicleType         0.335728     1.000000            0.006265  0.157965
# yearOfRegistration  0.467205     0.006265            1.000000  0.091571
# gearbox             0.329326     0.157965            0.091571  1.000000
# powerPS             0.566092     0.407713            0.155394  0.460782
# kilometer          -0.479364    -0.051141           -0.360817 -0.031604
# fuelType            0.274937     0.077382            0.283455  0.170182
# notRepairedDamage   0.165213     0.054117            0.087329  0.042760
#
#                      powerPS  kilometer  fuelType  notRepairedDamage
# price               0.566092  -0.479364  0.274937           0.165213
# vehicleType         0.407713  -0.051141  0.077382           0.054117
# yearOfRegistration  0.155394  -0.360817  0.283455           0.087329
# gearbox             0.460782  -0.031604  0.170182           0.042760
# powerPS             1.000000   0.015507  0.183454           0.048682
# kilometer           0.015507   1.000000  0.080740          -0.103931
# fuelType            0.183454   0.080740  1.000000           0.050624
# notRepairedDamage   0.048682  -0.103931  0.050624           1.000000

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, square=True, annot_kws={'fontsize':15})
plt.show()

# %%
df.sample(20)
# Out:
#       price  vehicleType  yearOfRegistration  gearbox  powerPS        model  \
# 230    1450          1.0                1999      1.0       75      2_reihe
# 2650  11500          3.0                2010      1.0      102  transporter
# 386    1350          1.0                2005      1.0       52        matiz
# 1095   1200          5.0                2000      1.0      107       scenic
# 2807  36500          8.0                2011      2.0      258      x_reihe
# 878    3500          6.0                2005      1.0      109      2_reihe
# 1499    350          2.0                1997      1.0      116       mondeo
# 53     7999          4.0                2008      2.0      143          3er
# 257    6799          4.0                2002      2.0      286          5er
# 1519   1550          4.0                1998      1.0      116        astra
# 141    2499          4.0                2003      1.0      110        civic
# 260   25900          7.0                2009      1.0      265       andere
# 1854   4999          8.0                2003      1.0      116          rav
# 516    6500          1.0                2012      1.0       81       fiesta
# 2823   4990          2.0                2003      2.0      250       andere
# 1858  12999          2.0                2010      1.0      136     c_klasse
# 925    1199          1.0                2000      1.0       60       fiesta
# 1594   3299          4.0                2001      1.0      150           a3
# 478    8100          2.0                2004      2.0      150     e_klasse
# 504   19900          5.0                2009      1.0      150        viano
#
#       kilometer  fuelType          brand  notRepairedDamage
# 230      150000       1.0        peugeot                2.0
# 2650      90000       6.0     volkswagen                2.0
# 386      150000       1.0      chevrolet                1.0
# 1095     150000       1.0        renault                2.0
# 2807      70000       6.0            bmw                2.0
# 878      150000       1.0        peugeot                2.0
# 1499      20000       1.0           ford                2.0
# 53       150000       6.0            bmw                2.0
# 257      150000       2.0            bmw                2.0
# 1519     150000       1.0           opel                2.0
# 141      150000       1.0          honda                2.0
# 260      125000       1.0        porsche                2.0
# 1854     150000       6.0         toyota                2.0
# 516       40000       1.0           ford                2.0
# 2823     150000       1.0           saab                2.0
# 1858     125000       6.0  mercedes_benz                2.0
# 925      125000       1.0           ford                2.0
# 1594     150000       1.0           audi                2.0
# 478      150000       6.0  mercedes_benz                2.0
# 504       90000       6.0  mercedes_benz                2.0

# %% [markdown]
# ### The useful features for our model are vehicle type, not repaired damage, fuel type, kilometer, power ps, gearbox, year of registration according to all the graphs above because they are positively or negatively correlated with the price.

# %% [markdown]
# ## Machine learning

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
X=df['powerPS'].values[:,np.newaxis]
y=df['price'].values
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=30)
model1=LinearRegression()
model1.fit(X_train, y_train)
predicted=model1.predict(X_test)
print("MSE :",metrics.mean_squared_error(y_test,predicted))
print("R squared :",metrics.r2_score(y_test,predicted))
# Out:
# MSE : 28312885.6103959
# R squared : 0.32360321189065777

# %%
plt.scatter(X,y, color='r')
plt.title("linear regression")
plt.ylabel("Price")
plt.xlabel("PowerPS")
plt.plot(X,model1.predict(X),color='k')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Multilinear Regression

# %%
X=df[['yearOfRegistration','powerPS','kilometer']]
y=df['price'].values
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=30)
model=LinearRegression()
model.fit(X_train, y_train)
predicted=model.predict(X_test)
print("MSE :",metrics.mean_squared_error(y_test,predicted))
print("R squared :",metrics.r2_score(y_test,predicted))
# Out:
# MSE : 14831393.310549404
# R squared : 0.645676991865552

# %% [markdown]
# ### Polynomial Regression

# %%
X=df[['yearOfRegistration','powerPS','kilometer','vehicleType','gearbox']]
y=df['price'].values
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=30)
model=LinearRegression()
poly=PolynomialFeatures(degree=3)
X_train_fit=poly.fit_transform(X_train)
model.fit(X_train_fit, y_train)
X_test=poly.fit_transform(X_test)
predicted=model.predict(X_test)
print("MSE :",metrics.mean_squared_error(y_test,predicted))
print("R squared :",metrics.r2_score(y_test,predicted))
# Out:
# MSE : 10450094.246930895
# R squared : 0.7503465283853441

# %% [markdown]
# ### The most accurate one is Polynomial regression with the highest MSE and R squared.

# %% [markdown]
# ### Agglomerative Clustering

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
df = df.drop(['brand'], axis=1)
df = df.drop(['model'], axis=1)

# %%
X=df[['yearOfRegistration','powerPS','kilometer','vehicleType','gearbox']]
y=df['price'].values
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=30)

# %%
model = AgglomerativeClustering(n_clusters=6, affinity='euclidean', linkage='complete')
clust_labels = model.fit_predict(df)

# %%
agglomerative = pd.DataFrame(clust_labels)
agglomerative
# Out:
#       0
# 0     2
# 1     2
# 2     2
# 3     1
# 4     2
# ...  ..
# 2463  3
# 2464  2
# 2465  2
# 2466  3
# 2467  0
#
# [2468 rows x 1 columns]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter(df['yearOfRegistration'], df['price'],c= agglomerative[0],s=50)
ax.set_title('Agglomerative Clustering')
ax.set_xlabel('YearOfRegistration')
ax.set_ylabel('Price')
plt.colorbar(scatter)

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10,7))
plt.title("Dendrograms")
dend=shc.dendrogram(shc.linkage(df, method="complete"))

# %% [markdown]
# ### Kmeans Clustering

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=5,random_state=0)
y_kmeans=kmeans.fit_predict(df)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter(df['yearOfRegistration'], df['price'],c=y_kmeans,s=50)
ax.set_title('KMeans Clustering')
ax.set_xlabel('YearOfRegistration')
ax.set_ylabel('Price')
plt.colorbar(scatter)

# %%
cost =[] 
for i in range(1, 15): 
    KM = KMeans(n_clusters = i, max_iter = 500) 
    KM.fit(df)  
    cost.append(KM.inertia_)

# %%
plt.plot(range(1, 15), cost, color ='g', linewidth ='3') 
plt.xlabel("Value of K") 
plt.ylabel("Sqaured Error (Cost)") 
plt.show()

# %% [markdown]
# #### The optimal value of K is 2

# %%
kmeans=KMeans(n_clusters=2,random_state=0)
y_kmeans=kmeans.fit_predict(df)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter(df['yearOfRegistration'], df['price'],c=y_kmeans,s=50)
ax.set_title('KMeans Clustering')
ax.set_xlabel('YearOfRegistration')
ax.set_ylabel('Price')
plt.colorbar(scatter)

# %% [markdown]
# # Thanks for your attention
